# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# In our previous data processing, we organized the data as follows: For each startup with a calculable company value, we identified the corresponding founder and arranged the founder's work experience chronologically by a defined index. The last index for each founding experience represents the startup we are investigating, along with its corresponding company value. The details can be found in the 'Define company value and Data filtering.ipynb'.
#
# We also utilize the verticals that prediced by OnevsRest, which is the'class_name' column in the following dataframe.

# %%
import pandas as pd
career = pd.read_csv('./drive/MyDrive/Capstone/7.11_data.csv')

# %%
career
# Out:
#        Unnamed: 0  CareerID  FounderID  CompanyID  \
# 0               0         8          1      53036
# 1               1         7          1      53036
# 2               2    216950          1      19921
# 3               3     80467          3      27310
# 4               4     80414          3      39824
# ...           ...       ...        ...        ...
# 11335       11335    238807      25746     127266
# 11336       11336    312809      25746     152402
# 11337       11337    238804      25746     127266
# 11338       11338    312807      25746     152400
# 11339       11339    238800      25746     127266
#
#                                             JobTitle          DateRange  \
# 0                                     Vise President          2005–2009
# 1                                 Executive Director          2007–2009
# 2                                            Founder    01/2016-Present
# 3                                    Lead Accountant  Nov 2001–Apr 2006
# 4      Manager of Finance and Accounting, CIS Region  May 2006–Oct 2008
# ...                                              ...                ...
# 11335          Chief Technical Officer  | co-founder    10/2015-12/2017
# 11336                             Product Strategist      1/2017-9/2018
# 11337             Chief Product Officer | co-founder    12/2017-01/2019
# 11338           Chief Executive Officer | co-founder     12/2018-3/2021
# 11339                                        Advisor    01/2019-12/2019
#
#        Start Date    End Date  Duration (years)                    Location  \
# 0      2005-03-01  2009-09-01               4.5                         NaN
# 1      2007-03-01  2009-09-01               2.5  Moscow, Russian Federation
# 2      2016-01-01         NaN               6.4                      Cyprus
# 3      2001-11-01  2006-04-01               4.4                         NaN
# 4      2006-05-01  2008-10-01               2.4                         NaN
# ...           ...         ...               ...                         ...
# 11335  2015-10-01  2017-12-01               2.2        Toronto, Canada Area
# 11336  2017-01-01  2018-09-01               1.7                         NaN
# 11337  2017-12-01  2019-01-01               1.1        Toronto, Canada Area
# 11338  2018-12-01  2021-03-01               2.2                         NaN
# 11339  2019-01-01  2019-12-01               0.9                         NaN
#
#                                              Description Created Date  \
# 0                                                    NaN   2021-02-19
# 1                                                    NaN   2021-02-19
# 2      We are the largest global \ntravel mobility ma...   2022-05-05
# 3                                                    NaN   2021-03-10
# 4                                                    NaN   2021-03-10
# ...                                                  ...          ...
# 11335                                                NaN   2022-06-17
# 11336                                                NaN   2023-03-29
# 11337                                                NaN   2022-06-17
# 11338  Inkblot was acquired by Green Shield Holdings ...   2023-03-29
# 11339                                                NaN   2022-06-17
#
#        Relevant  founded_company_value Headquarters Location  \
# 0         False                    NaN                   NaN
# 1         False                    NaN                   NaN
# 2          True             22450000.0   European Union (EU)
# 3         False                    NaN                   NaN
# 4         False                    NaN                   NaN
# ...         ...                    ...                   ...
# 11335      True             12500000.0      Toronto, Ontario
# 11336     False                    NaN                   NaN
# 11337      True             12500000.0      Toronto, Ontario
# 11338      True              3808640.0                   NaN
# 11339     False             12500000.0      Toronto, Ontario
#
#       Number Of Employees  index  \
# 0                     NaN      0
# 1                     NaN      1
# 2                     NaN      2
# 3                     NaN      0
# 4                     NaN      1
# ...                   ...    ...
# 11335               11-50      4
# 11336                 NaN      5
# 11337               11-50      6
# 11338                 NaN      7
# 11339               11-50      8
#
#                                               class_name
# 0                                                    NaN
# 1                                                    NaN
# 2      Carsharing,Micro-mobility,Mobility tech,Ridesh...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11335                                             HRtech
# 11336                                                NaN
# 11337                                             HRtech
# 11338                                                NaN
# 11339                                             HRtech
#
# [11340 rows x 18 columns]

# %% [markdown]
# ## Basic variables calculation

# %% [markdown]
# Here we use a function to calculate basic variables, which are 'Number of professional experience','Number of companies that worked for', 'Total Work Years','Industry Experience', 'Management experience','Entrepreneurial Experience', 'Technical experience', 'Location' and 'Vertical' for each founding experience.

# %%
# Create a new column 'group' where each group starts with index = 0 (created in the last step)
# The index = 0 indicates that start of one specific founding experience
career['group'] = (career.iloc[:, 16] == 0).cumsum()

# Group the dataframe by the new 'group' column
grouped = career.groupby('group')

result_dfs = []

for founder_id, group in grouped:
    # The last row in the group is assumed to be the startup experience
    startup_row = group.iloc[-1]
    # All rows except the last one are assumed to be work experience
    work_experience = group.iloc[:-1]

    # Extract the founder ID
    founder_id = startup_row['FounderID']
    # Extract the company ID
    company_id = startup_row['CompanyID']
    # Extract the career ID
    career_id = startup_row['CareerID']
    # Extract the location
    location = startup_row['Location']
    # Extract the vertical
    vertical = startup_row['class_name']

    # Calculate the total years of work experience
    total_years = work_experience['Duration (years)'].sum()

    # Count the number of professional experiences
    num_professional_experience = len(work_experience)

    # Count the number of unique companies worked for
    num_worked_companies = work_experience['CompanyID'].nunique()

    # Calculate the vertical-specific work experience
    industry_experience = work_experience[work_experience['class_name'] == startup_row['class_name']]['Duration (years)'].sum()

    # Define keywords for management positions
    management_keywords = [
      "aufsichtsrat", "board", "cco", "ceo", "cfo", "chairman", "chairwoman", "chief", "cmo", "cpo",
      "cro", "cto", "director", "executive", "general director", "general manager", "geschaeftsfuehrer",
      "head", "lead", "partner", "projektleiter", "president", "verwaltungsrat", "vorstand", "vr"]
    # Calculate the management experience
    group_mask_management = work_experience['JobTitle'].str.contains('|'.join(management_keywords), case=False, na=False)
    management_experience = work_experience[group_mask_management]['Duration (years)'].sum()

    # Define keywords for entrepreneurial positions
    entrepreneurial_keywords = [
        "angel", "cofounder", "founder", "partner", "gruender", "inhaber", "initiator",
        "investor", "mitgruender", "owner",  "co-founder", 'entrepreneur']
    # Calculate the entrepreneurial experience
    group_mask_entrepreneurial = work_experience['JobTitle'].str.contains('|'.join(entrepreneurial_keywords), case=False, na=False)
    entrepreneurial_experience = work_experience[group_mask_entrepreneurial]['Duration (years)'].sum()

    # Define keywords for technical positions
    technical_keywords = [
        "architect", "intelligence", "computer", "cto", "data", "developer", "development" ,'scientist', 'architect',
        "engineer", "engineering", "programmer", "system", "technical", "technology", 'economist', 'researcher'
    ]
    # Calculate the technical experience
    group_mask_technical = work_experience['JobTitle'].str.contains('|'.join(technical_keywords), case=False, na=False)
    technical_experience = work_experience[group_mask_technical]['Duration (years)'].sum()

    # Extract the value of the founded company
    founded_company_value = startup_row['founded_company_value']

    # Build the result dataframe for the current group
    result_df = pd.DataFrame({
        'FounderID': [founder_id],
        'CompanyID': [company_id],
        'CareerID': [career_id],
        'Number of professional experience': [num_professional_experience],
        'Number of companies that worked for': [num_worked_companies],
        'Total Work Years': [total_years],
        'Industry Experience': [industry_experience],
        'Management experience': [management_experience],
        'Entrepreneurial Experience': [entrepreneurial_experience],
        'Technical experience': [technical_experience],
        'Founded Company Value': [founded_company_value],
        'Location':[location],
        'Vertical':[vertical]
    })

    result_dfs.append(result_df)

# Concatenate all the result dataframes into one final dataframe
final_result_df = pd.concat(result_dfs, ignore_index=True)

final_result_df.head(20)
# Out:
#     FounderID  CompanyID  CareerID  Number of professional experience  \
# 0           1      19921    216950                                  2
# 1           3      17160     79402                                  8
# 2           6      19921        39                                  7
# 3          13      20739       107                                  3
# 4          28      50729       223                                  7
# 5          48      33123       343                                  0
# 6          58      33123       391                                  0
# 7          63      16427       429                                  7
# 8          81      53981     87155                                 10
# 9          83      40324       566                                 12
# 10        116      24836       787                                  4
# 11        131      41453    190630                                  3
# 12        145      22344       964                                  1
# 13        150     145827    296546                                  5
# 14        220     130645    251397                                  7
# 15        266      15816      1636                                  1
# 16        270      18387      1655                                  2
# 17        283      29468    322328                                 14
# 18        299      27766     72388                                  8
# 19        367      46115    183275                                  0
#
#     Number of companies that worked for  Total Work Years  \
# 0                                     1               7.0
# 1                                     8              31.1
# 2                                     6              18.9
# 3                                     3               7.1
# 4                                     7               7.2
# 5                                     0               0.0
# 6                                     0               0.0
# 7                                     6               6.0
# 8                                     9              15.6
# 9                                     7              28.9
# 10                                    3               3.2
# 11                                    3               1.5
# 12                                    1              22.4
# 13                                    5               7.3
# 14                                    7              19.8
# 15                                    1               0.2
# 16                                    2               2.6
# 17                                   13              20.0
# 18                                    8              17.5
# 19                                    0               0.0
#
#     Industry Experience  Management experience  Entrepreneurial Experience  \
# 0                   0.0                    7.0                         0.0
# 1                   0.0                   19.6                         9.9
# 2                   0.0                   10.3                         0.0
# 3                   0.0                    0.0                         0.0
# 4                   0.0                    5.5                         0.0
# 5                   0.0                    0.0                         0.0
# 6                   0.0                    0.0                         0.0
# 7                   0.0                    2.3                         0.0
# 8                   0.0                    2.3                         0.0
# 9                   0.0                   13.3                         0.0
# 10                  0.0                    0.5                         0.0
# 11                  0.0                    0.0                         0.0
# 12                  0.0                   22.4                        22.4
# 13                  0.0                    2.3                         4.6
# 14                  0.0                   10.1                         0.0
# 15                  0.0                    0.0                         0.0
# 16                  0.0                    0.0                         0.0
# 17                  0.0                    0.0                        13.6
# 18                  0.0                   10.2                         4.0
# 19                  0.0                    0.0                         0.0
#
#     Technical experience  Founded Company Value  \
# 0                    2.5           2.245000e+07
# 1                    0.0           1.185246e+07
# 2                    6.7           2.245000e+07
# 3                    4.1           3.504100e+05
# 4                    0.0           3.000000e+07
# 5                    0.0           6.500000e+06
# 6                    0.0           6.500000e+06
# 7                    0.2           1.825000e+06
# 8                    1.5           7.305800e+05
# 9                   13.2           3.637125e+06
# 10                   0.0           2.000000e+09
# 11                   0.0           3.000000e+06
# 12                   0.0           3.900000e+09
# 13                   0.0           1.000000e+06
# 14                   8.0           2.747115e+06
# 15                   0.0           5.500000e+06
# 16                   0.0           1.000000e+07
# 17                   2.8           1.500000e+07
# 18                   6.9           1.200000e+07
# 19                   0.0           1.650000e+07
#
#                                  Location  \
# 0                                  Cyprus
# 1                                     NaN
# 2                                   World
# 3                  London, United Kingdom
# 4                                     NaN
# 5                                     NaN
# 6                                  Moscow
# 7                        Istanbul, Turkey
# 8                        Istanbul, Turkey
# 9                        Istanbul, Turkey
# 10                                    NaN
# 11                       Istanbul, Turkey
# 12                       Istanbul, Turkey
# 13                      İstanbul, Türkiye
# 14             Ireland, London, EMEA, US
# 15                                Nairobi
# 16  Cape Town, Western Cape, South Africa
# 17                         Lagos, Nigeria
# 18    Lagos, Nigeria & San Francisco, USA
# 19                         Lagos, Nigeria
#
#                                              Vertical
# 0   Carsharing,Micro-mobility,Mobility tech,Ridesh...
# 1                       Cryptocurrency and blockchain
# 2   Carsharing,Micro-mobility,Mobility tech,Ridesh...
# 3                                            Foodtech
# 4                       Cryptocurrency and blockchain
# 5                                            Foodtech
# 6                                            Foodtech
# 7   Carsharing,Micro-mobility,Mobility tech,Ridesh...
# 8   Carsharing,Micro-mobility,Mobility tech,Ridesh...
# 9                                              HRtech
# 10                       B2B payments,Mobile commerce
# 11                                    Restaurant tech
# 12                                          Ecommerce
# 13                            Supply chain technology
# 14                                          Audiotech
# 15                                Robotics and drones
# 16                                             Edtech
# 17                                         Healthtech
# 18                                            Fintech
# 19                                          Audiotech

# %%
final_result_df.shape
# Out:
# (1801, 15)

# %% [markdown]
# ## Location Cleaning

# %% [markdown]
# The text in the location variable contains numerous issues, such as various symbols, inconsistent capitalization, and many non-English values. Therefore, we need to preprocess, translate, and clean this variable. The specific steps are as follows:
#
# 1. preprocessing_text: First, convert all text to lowercase and remove content within square brackets, links, HTML tags, punctuation, newline characters, and email addresses. This step ensures consistency and standardization of the text.
#
# 2. translation: Since many values are not in English, we use the googletrans library to translate the text into English, ensuring all text is in English for subsequent processing and analysis.
#
# 3. text_clean: After preprocessing and translation, we further clean the text to ensure the final text is properly formatted and free of extraneous special characters.

# %% [markdown]
# **Data Translating**

# %%
import re
import string

def preprocess_text(text):
    '''Make text lowercase, remove text in square brackets, remove links, remove punctuation
    and remove words containing numbers.'''
    '''remove email'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\S+@\S+', '', text)

    return text

#5.translate
def translate(text):
  translator = Translator(service_urls=['translate.googleapis.com'])
  translated_text=translator.translate(text, dest='en').text
  return translated_text

def text_clean(text):
    remove_special = preprocess_text(text)
    if remove_special=='':
      tran_text = remove_special
    else:
      tran_text = translate(remove_special)
    return tran_text

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.7.4)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2024.7.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 22.6 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.9 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 7.6 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 8.7 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 10.8 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16353 sha256=58cec0d3949de35e811dbbafc9c1c26affe69f2dc96a548e090b5bb72ac709fd
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.7.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
from googletrans import Translator
# Apply function to the location variable
final_result_df["Location"] = final_result_df["Location"].map(preprocess_text)
final_result_df["Location"] = final_result_df["Location"].map(translate)
final_result_df["Location"] = final_result_df["Location"].map(text_clean)

# %%
# Distribution of the counts of location
location_counts = final_result_df['Location'].value_counts()

print(location_counts[:50])
# Out:
# Location
# in                                              473
# london united kingdom                           165
# san francisco bay area                           78
# london england united kingdom                    74
# greater new york city area                       55
# singapore                                        28
# london                                           18
# paris area france                                16
# berlin germany                                   16
# new york united states                           14
# berlin area germany                              14
# greater los angeles area                         13
# barcelona area spain                             10
# stockholm sweden                                 10
# san francisco                                     9
# toronto canada area                               9
# new york new york united states                   8
# los angeles california united states              8
# new delhi area india                              8
# the new york                                      8
# berlin                                            7
# greater san diego area                            7
# mexico city area mexico                           7
# Paris region France                               7
# milan area italy                                  7
# istanbul turkey                                   7
# new york city                                     6
# copenhagen capital region denmark                 6
# new york                                          6
# Berlin, Germany                                   6
# São Paulo area Brazil                             6
# amsterdam north holland netherlands               6
# mumbai area india                                 6
# Kuala Lumpur, Malaysia                            6
# new york city metropolitan area                   6
# amsterdam area netherlands                        6
# greater boston area                               6
# madrid area spain                                 5
# barcelona catalonia spain                         5
# Berlin and the surrounding area of ​​Germany      5
# bengaluru area india                              5
# munich area germany                               5
# dubai united arab emirates                        5
# chicago il                                        5
# gurgaon india                                     5
# oslo norway                                       5
# Nairobi Kenya                                     5
# united states                                     5
# oslo area norway                                  5
# greater seattle area                              4
# Name: count, dtype: int64

# %% [markdown]
# **Define Location Name**

# %% [markdown]
# After standardizing the text and translating non-English text, we found that the 'location' data contains repeated locations, such as 'london united kingdom', 'london england united kingdom', and 'london'. To group these repeated locations together, we use the clean_location function.

# %%
import re

def clean_location(location):
    if re.search(r'\blondon\b', location, re.IGNORECASE):
        return 'london'
    elif re.search(r'\bnew york\b|\bnyc\b', location, re.IGNORECASE):
        return 'new york'
    elif re.search(r'\bsan francisco\b', location, re.IGNORECASE):
        return 'san francisco'
    elif re.search(r'\bsingapore\b', location, re.IGNORECASE):
        return 'singapore'
    elif re.search(r'\bwashington\b', location, re.IGNORECASE):
        return 'washington'
    elif re.search(r'\bbarcelona\b', location, re.IGNORECASE):
        return 'barcelona'
    elif re.search(r'\bparis\b', location, re.IGNORECASE):
        return 'paris'
    elif re.search(r'\blos angeles\b', location, re.IGNORECASE):
        return 'los angeles'
    elif re.search(r'\bberlin\b', location, re.IGNORECASE):
        return 'berlin'
    elif re.search(r'\bstockholm\b', location, re.IGNORECASE):
        return 'stockholm'
    elif re.search(r'\bmilan\b', location, re.IGNORECASE):
        return 'milan'
    elif re.search(r'\bboston\b', location, re.IGNORECASE):
        return 'boston'
    elif re.search(r'\bmumbai\b', location, re.IGNORECASE):
        return 'mumbai'
    elif re.search(r'\bmadrid\b', location, re.IGNORECASE):
        return 'madrid'
    elif re.search(r'\bcopenhagen\b', location, re.IGNORECASE):
        return 'copenhagen'
    elif re.search(r'\bamsterdam\b', location, re.IGNORECASE):
        return 'amsterdam'
    elif re.search(r'\bnew delhi\b', location, re.IGNORECASE):
        return 'new delhi'
    elif re.search(r'\bhong kong\b', location, re.IGNORECASE):
        return 'hong kong'
    elif re.search(r'\bbrussels\b', location, re.IGNORECASE):
        return 'brussels'
    elif re.search(r'\bmunich\b', location, re.IGNORECASE):
        return 'munich'
    elif re.search(r'\bmexico\b', location, re.IGNORECASE):
        return 'mexico'
    elif re.search(r'\bchicago\b', location, re.IGNORECASE):
        return 'chicago'
    elif re.search(r'\boxford\b', location, re.IGNORECASE):
        return 'oxford'
    elif re.search(r'\bistanbul\b', location, re.IGNORECASE):
        return 'istanbul'
    elif re.search(r'\bSão Paulo\b|\bSao Paulo\b', location, re.IGNORECASE):
        return 'sao paulo'
    elif re.search(r'\bhelsinki\b', location, re.IGNORECASE):
        return 'helsinki'
    elif re.search(r'\bvienna\b', location, re.IGNORECASE):
        return 'vienna'
    elif re.search(r'\bmoscow\b', location, re.IGNORECASE):
        return 'moscow'
    elif re.search(r'\btoronto\b', location, re.IGNORECASE):
        return 'toronto'
    elif re.search(r'\bsan diego\b', location, re.IGNORECASE):
        return 'san diego'
    elif re.search(r'\bcambridge\b', location, re.IGNORECASE):
        return 'cambridge'
    elif re.search(r'\bdubai\b', location, re.IGNORECASE):
        return 'dubai'
    elif re.search(r'\boslo\b', location, re.IGNORECASE):
        return 'oslo'
    elif re.search(r'\bzürich\b|\bzurich\b', location, re.IGNORECASE):
        return 'zurich'
    elif re.search(r'\bnairobi\b', location, re.IGNORECASE):
        return 'nairobi'
    elif re.search(r'\bfrankfurt\b', location, re.IGNORECASE):
        return 'frankfurt'
    elif re.search(r'\blisbon\b', location, re.IGNORECASE):
        return 'lisbon'
    elif re.search(r'\bbeijing\b', location, re.IGNORECASE):
        return 'beijing'
    elif re.search(r'\bmontreal\b', location, re.IGNORECASE):
        return 'montreal'
    elif re.search(r'\bshanghai\b', location, re.IGNORECASE):
        return 'shanghai'
    elif re.search(r'\bKuala Lumpur\b', location, re.IGNORECASE):
        return 'kuala lumpur'
    elif re.search(r'\bbengaluru\b', location, re.IGNORECASE):
        return 'bengaluru'
    elif re.search(r'\bphiladelphia\b', location, re.IGNORECASE):
        return 'philadelphia'
    elif re.search(r'\bgreece\b', location, re.IGNORECASE):
        return 'greece'
    elif re.search(r'\bsydney\b', location, re.IGNORECASE):
        return 'sydney'
    elif re.search(r'\bseattle\b', location, re.IGNORECASE):
        return 'seattle'
    elif re.search(r'\bprague\b', location, re.IGNORECASE):
        return 'prague'
    elif re.search(r'\bgurgaon\b', location, re.IGNORECASE):
        return 'gurgaon'
    elif re.search(r'\blagos\b', location, re.IGNORECASE):
        return 'lagos'
    else:
        return location

# %%
# Apply function to the location variable
final_result_df['Location'] = final_result_df['Location'].apply(clean_location)

# %%
# Distribution of the counts of cleaned location
location_counts = final_result_df['Location'].value_counts()

print(location_counts[:50])
# Out:
# Location
# in                             473
# london                         302
# new york                       117
# san francisco                  105
# berlin                          55
# paris                           33
# singapore                       32
# los angeles                     24
# barcelona                       21
# boston                          18
# mexico                          18
# toronto                         17
# munich                          16
# milan                           16
# stockholm                       15
# oslo                            15
# chicago                         15
# sao paulo                       15
# mumbai                          14
# copenhagen                      14
# madrid                          13
# amsterdam                       12
# new delhi                       12
# cambridge                       11
# bengaluru                       10
# kuala lumpur                     9
# san diego                        8
# dubai                            8
# zurich                           8
# hong kong                        8
# istanbul                         8
# washington                       7
# seattle                          7
# vienna                           7
# nairobi                          6
# gurgaon                          6
# greece                           6
# beijing                          5
# oxford                           5
# united states                    5
# brussels                         4
# helsinki                         4
# india                            4
# lagos                            4
# prague                           4
# lisbon                           3
# cape town area south africa      3
# uk                               3
# united kingdom                   3
# moscow                           3
# Name: count, dtype: int64

# %%
# Define the list of cities with frequency larger than 5
cities = [
    'london', 'new york', 'san francisco', 'berlin', 'paris',
    'singapore', 'los angeles', 'barcelona', 'boston', 'mexico',
    'toronto', 'munich', 'milan', 'stockholm', 'oslo', 'chicago',
    'sao paulo', 'mumbai', 'copenhagen', 'madrid', 'amsterdam',
    'new delhi', 'cambridge', 'bengaluru', 'kuala lumpur', 'san diego',
    'dubai', 'zurich', 'hong kong', 'istanbul', 'washington', 'seattle',
    'vienna', 'nairobi', 'gurgaon', 'greece', 'beijing', 'oxford',
    'united states'
]

# %%
# Cities with frequency smaller than 5 are classfied to others
final_result_df['Location'] = final_result_df['Location'].apply(lambda x: x if x in cities else 'other')

# %%
final_result_df['Location'].nunique()
# Out:
# 40

# %% [markdown]
# ## Job Title and Speed of growth

# %% [markdown]
# In this section, we utilize the information in the job title and define the speed of growth.

# %% [markdown]
# ### Job Title Cleaning

# %%
# !pip install langdetect
# !pip install googletrans==3.1.0a0
from googletrans import Translator
from langdetect import detect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=b2b2fb018e09ed481cb693dafe8dc1cba3604c7493fb859734df37c23cdf1268
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.6.2)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2024.7.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 9.4 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 10.1 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.7 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 8.0 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.7 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16353 sha256=722e20e9791897641b7c74ab4c74b53eba15dd8d2e18254cf1b615d65aa7732f
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.7.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
# Data Cleaning
career.dropna(subset=['JobTitle'], inplace=True)
career['JobTitle'] = career['JobTitle'].str.lower()

import re
def remove_punctuation_and_replace_with_space(text):
  text = re.sub(r'[^\w\s-]', ' ', text)
  return re.sub(r'\s+', ' ', text).strip()


career['JobTitle'] = career['JobTitle'].apply(remove_punctuation_and_replace_with_space)

# %%
def translate(text):
  translator = Translator(service_urls=['translate.googleapis.com'])
  translated_text=translator.translate(text, dest='en').text
  return translated_text

career['JobTitle'] = career['JobTitle'].apply(translate)

# %% [markdown]
# ### Creat Job Level Dictionary

# %%
career.dropna(subset=['JobTitle'], inplace=True)
career['JobTitle'] = career['JobTitle'].str.replace('-', ' ')
career['JobTitle'] = career['JobTitle'].str.lower()

# %%
# Words Frequency
from collections import Counter

def count_word_frequencies(df, column_name):
    word_counts = Counter()
    for title in df[column_name]:
        words = title.split()
        word_counts.update(words)
    return word_counts

career_word_counts = count_word_frequencies(career, 'JobTitle')

career_word_counts.most_common()
# Out:
# [('founder', 2804),
#  ('co', 1936),
#  ('and', 1005),
#  ('ceo', 977),
#  ('director', 912),
#  ('manager', 899),
#  ('of', 805),
#  ('analyst', 706),
#  ('intern', 669),
#  ('consultant', 591),
#  ('business', 549),
#  ('associate', 545),
#  ('officer', 465),
#  ('development', 448),
#  ('chief', 448),
#  ('board', 405),
#  ('senior', 397),
#  ('product', 373),
#  ('member', 361),
#  ('head', 354),
#  ('executive', 347),
#  ('president', 338),
#  ('marketing', 323),
#  ('research', 291),
#  ('investment', 286),
#  ('advisor', 271),
#  ('managing', 265),
#  ('strategy', 263),
#  ('assistant', 260),
#  ('partner', 256),
#  ('summer', 253),
#  ('project', 219),
#  ('management', 216),
#  ('sales', 214),
#  ('vice', 209),
#  ('coo', 196),
#  ('the', 196),
#  ('finance', 188),
#  ('investor', 182),
#  ('global', 174),
#  ('banking', 156),
#  ('operations', 153),
#  ('corporate', 147),
#  ('chairman', 144),
#  ('lead', 134),
#  ('in', 130),
#  ('financial', 129),
#  ('equity', 117),
#  ('engineer', 105),
#  ('fellow', 104),
#  ('vp', 101),
#  ('at', 98),
#  ('a', 98),
#  ('cfo', 93),
#  ('internship', 93),
#  ('program', 93),
#  ('group', 92),
#  ('principal', 92),
#  ('strategic', 90),
#  ('for', 90),
#  ('team', 88),
#  ('student', 86),
#  ('digital', 86),
#  ('international', 85),
#  ('general', 81),
#  ('to', 77),
#  ('trainee', 75),
#  ('m', 75),
#  ('services', 74),
#  ('private', 74),
#  ('data', 71),
#  ('account', 70),
#  ('software', 70),
#  ('researcher', 67),
#  ('advisory', 66),
#  ('cto', 65),
#  ('owner', 64),
#  ('developer', 63),
#  ('entrepreneur', 62),
#  ('markets', 60),
#  ('growth', 60),
#  ('lecturer', 59),
#  ('visiting', 59),
#  ('founding', 59),
#  ('venture', 59),
#  ('operating', 59),
#  ('coordinator', 58),
#  ('leader', 57),
#  ('trader', 57),
#  ('directors', 56),
#  ('junior', 56),
#  ('risk', 55),
#  ('professor', 55),
#  ('technology', 55),
#  ('commercial', 54),
#  ('technical', 52),
#  ('credit', 51),
#  ('trading', 51),
#  ('specialist', 50),
#  ('office', 49),
#  ('department', 49),
#  ('consulting', 49),
#  ('non', 49),
#  ('legal', 47),
#  ('capital', 47),
#  ('policy', 46),
#  ('market', 45),
#  ('media', 45),
#  ('scientist', 45),
#  ('solutions', 44),
#  ('mentor', 44),
#  ('communications', 44),
#  ('editor', 44),
#  ('innovation', 43),
#  ('staff', 42),
#  ('division', 41),
#  ('engagement', 41),
#  ('uk', 40),
#  ('brand', 39),
#  ('graduate', 39),
#  ('affairs', 38),
#  ('analytics', 37),
#  ('it', 37),
#  ('deputy', 36),
#  ('social', 36),
#  ('derivatives', 36),
#  ('regional', 35),
#  ('new', 35),
#  ('asia', 35),
#  ('residence', 34),
#  ('planning', 33),
#  ('income', 33),
#  ('europe', 33),
#  ('emea', 33),
#  ('cofounder', 33),
#  ('fixed', 32),
#  ('economic', 32),
#  ('acquisitions', 32),
#  ('engineering', 32),
#  ('tech', 32),
#  ('economist', 32),
#  ('health', 32),
#  ('mobile', 32),
#  ('intelligence', 31),
#  ('portfolio', 31),
#  ('committee', 31),
#  ('professional', 31),
#  ('teacher', 31),
#  ('public', 31),
#  ('tutor', 30),
#  ('chair', 30),
#  ('investments', 30),
#  ('strategist', 29),
#  ('programme', 29),
#  ('freelance', 29),
#  ('customer', 28),
#  ('partnerships', 28),
#  ('teaching', 28),
#  ('audit', 28),
#  ('service', 28),
#  ('products', 28),
#  ('trade', 27),
#  ('architect', 27),
#  ('fund', 26),
#  ('acquired', 26),
#  ('european', 26),
#  ('startup', 26),
#  ('support', 25),
#  ('mba', 25),
#  ('lawyer', 25),
#  ('designer', 25),
#  ('content', 25),
#  ('relations', 25),
#  ('on', 25),
#  ('asset', 24),
#  ('consumer', 24),
#  ('retail', 24),
#  ('experience', 24),
#  ('center', 24),
#  ('client', 24),
#  ('logistics', 23),
#  ('law', 23),
#  ('adviser', 23),
#  ('coach', 23),
#  ('user', 23),
#  ('science', 22),
#  ('economics', 22),
#  ('tax', 22),
#  ('mergers', 22),
#  ('energy', 22),
#  ('svp', 21),
#  ('representative', 21),
#  ('s', 21),
#  ('analysis', 21),
#  ('national', 20),
#  ('projects', 20),
#  ('md', 20),
#  ('quantitative', 20),
#  ('angel', 20),
#  ('internal', 20),
#  ('communication', 20),
#  ('candidate', 19),
#  ('volunteer', 19),
#  ('special', 19),
#  ('design', 19),
#  ('systems', 19),
#  ('external', 19),
#  ('counsel', 18),
#  ('interim', 18),
#  ('pr', 18),
#  ('enterprise', 18),
#  ('independent', 18),
#  ('school', 18),
#  ('expert', 17),
#  ('producer', 17),
#  ('sector', 17),
#  ('online', 17),
#  ('by', 17),
#  ('google', 17),
#  ('emerging', 17),
#  ('region', 16),
#  ('care', 16),
#  ('america', 16),
#  ('transformation', 16),
#  ('debt', 16),
#  ('cmo', 16),
#  ('practice', 16),
#  ('acquisition', 16),
#  ('treasury', 16),
#  ('writer', 16),
#  ('tmt', 16),
#  ('hr', 15),
#  ('country', 15),
#  ('structured', 15),
#  ('ambassador', 15),
#  ('production', 15),
#  ('web', 15),
#  ('company', 15),
#  ('council', 15),
#  ('observer', 15),
#  ('instructor', 14),
#  ('e', 14),
#  ('fintech', 14),
#  ('infrastructure', 14),
#  ('creative', 14),
#  ('trustee', 14),
#  ('field', 14),
#  ('expansion', 14),
#  ('equities', 14),
#  ('key', 14),
#  ('access', 14),
#  ('phd', 14),
#  ('talent', 13),
#  ('journalist', 13),
#  ('resident', 13),
#  ('performance', 13),
#  ('medical', 13),
#  ('secretary', 13),
#  ('security', 13),
#  ('cio', 13),
#  ('institute', 13),
#  ('msc', 13),
#  ('adjunct', 13),
#  ('foreign', 13),
#  ('platform', 13),
#  ('north', 13),
#  ('entrepreneurship', 13),
#  ('network', 13),
#  ('lab', 13),
#  ('human', 13),
#  ('east', 13),
#  ('africa', 13),
#  ('r', 13),
#  ('accountant', 12),
#  ('information', 12),
#  ('minister', 12),
#  ('commodities', 12),
#  ('government', 12),
#  ('community', 12),
#  ('internet', 12),
#  ('us', 12),
#  ('advanced', 12),
#  ('academic', 12),
#  ('event', 12),
#  ('operator', 12),
#  ('pacific', 12),
#  ('desk', 12),
#  ('change', 12),
#  ('administrative', 12),
#  ('i', 12),
#  ('accounting', 11),
#  ('time', 11),
#  ('london', 11),
#  ('commerce', 11),
#  ('healthcare', 11),
#  ('cpo', 11),
#  ('bank', 11),
#  ('english', 11),
#  ('controller', 11),
#  ('wealth', 11),
#  ('banker', 11),
#  ('scholar', 11),
#  ('fx', 11),
#  ('prime', 11),
#  ('attorney', 11),
#  ('family', 10),
#  ('part', 10),
#  ('supply', 10),
#  ('studies', 10),
#  ('high', 10),
#  ('real', 10),
#  ('estate', 10),
#  ('organizer', 10),
#  ('contract', 10),
#  ('clerk', 10),
#  ('cloud', 10),
#  ('sr', 10),
#  ('leadership', 10),
#  ('events', 10),
#  ('middle', 10),
#  ('insights', 10),
#  ('india', 10),
#  ('assurance', 10),
#  ('correspondent', 10),
#  ('cohort', 10),
#  ('campaign', 10),
#  ('guest', 10),
#  ('up', 10),
#  ('benelux', 10),
#  ('start', 10),
#  ('d', 10),
#  ('seed', 10),
#  ('transaction', 9),
#  ('distribution', 9),
#  ('contributor', 9),
#  ('insurance', 9),
#  ('securities', 9),
#  ('area', 9),
#  ('investing', 9),
#  ('industry', 9),
#  ('integration', 9),
#  ('employee', 9),
#  ('ventures', 9),
#  ('acting', 9),
#  ('food', 9),
#  ('resources', 9),
#  ('solicitor', 9),
#  ('exchange', 9),
#  ('undergraduate', 9),
#  ('various', 9),
#  ('reporter', 9),
#  ('unit', 9),
#  ('supervisor', 9),
#  ('ecommerce', 9),
#  ('french', 9),
#  ('industrial', 9),
#  ('vc', 9),
#  ('university', 9),
#  ('auditor', 9),
#  ('vacation', 9),
#  ('shareholder', 8),
#  ('administrator', 8),
#  ('administration', 8),
#  ('ireland', 8),
#  ('pre', 8),
#  ('chain', 8),
#  ('sustainability', 8),
#  ('host', 8),
#  ('latam', 8),
#  ('film', 8),
#  ('programmer', 8),
#  ('travel', 8),
#  ('early', 8),
#  ('partners', 8),
#  ('working', 8),
#  ('learning', 8),
#  ('political', 8),
#  ('automotive', 8),
#  ('sustainable', 8),
#  ('computer', 8),
#  ('alliances', 8),
#  ('evp', 8),
#  ('economy', 8),
#  ('impact', 8),
#  ('revenue', 8),
#  ('course', 8),
#  ('commander', 8),
#  ('medicine', 8),
#  ('trustees', 8),
#  ('portal', 8),
#  ('quant', 8),
#  ('gm', 8),
#  ('b2b', 8),
#  ('sold', 8),
#  ('camp', 7),
#  ('pricing', 7),
#  ('latin', 7),
#  ('institutions', 7),
#  ('speaker', 7),
#  ('2018', 7),
#  ('publishing', 7),
#  ('career', 7),
#  ('curator', 7),
#  ('section', 7),
#  ('work', 7),
#  ('resource', 7),
#  ('quality', 7),
#  ('hedge', 7),
#  ('options', 7),
#  ('scientific', 7),
#  ('affiliate', 7),
#  ('campus', 7),
#  ('south', 7),
#  ('doctor', 7),
#  ('master', 7),
#  ('power', 7),
#  ('advertising', 7),
#  ('columnist', 7),
#  ('central', 7),
#  ('israel', 7),
#  ('spring', 7),
#  ('institutional', 7),
#  ('microsoft', 7),
#  ('clinical', 7),
#  ('doctoral', 7),
#  ('editorial', 7),
#  ('relationship', 7),
#  ('industrials', 7),
#  ('former', 7),
#  ('strength', 7),
#  ('conditioning', 7),
#  ('das', 7),
#  ('accelerate', 7),
#  ('video', 7),
#  ('turnaround', 7),
#  ('an', 6),
#  ('tv', 6),
#  ('personal', 6),
#  ('job', 6),
#  ('placement', 6),
#  ('training', 6),
#  ('jr', 6),
#  ('radio', 6),
#  ('litigation', 6),
#  ('paralegal', 6),
#  ('news', 6),
#  ('post', 6),
#  ('transfer', 6),
#  ('property', 6),
#  ('machine', 6),
#  ('organizational', 6),
#  ('consultancy', 6),
#  ('sports', 6),
#  ('search', 6),
#  ('broadcast', 6),
#  ('cso', 6),
#  ('society', 6),
#  ('programs', 6),
#  ('mena', 6),
#  ('guide', 6),
#  ('publisher', 6),
#  ('young', 6),
#  ('accounts', 6),
#  ('alumni', 6),
#  ('asian', 6),
#  ('procurement', 6),
#  ('academy', 6),
#  ('hospitality', 6),
#  ('governance', 6),
#  ('currencies', 6),
#  ('foundation', 6),
#  ('mathematics', 6),
#  ('house', 6),
#  ('series', 6),
#  ('steering', 6),
#  ('leveraged', 6),
#  ('russia', 6),
#  ('author', 6),
#  ('planner', 6),
#  ('scheme', 6),
#  ('u', 6),
#  ('saas', 6),
#  ('faculty', 6),
#  ('physician', 6),
#  ('life', 6),
#  ('grad', 6),
#  ('system', 6),
#  ('process', 6),
#  ('fundraising', 6),
#  ('roles', 6),
#  ('android', 6),
#  ('hk', 6),
#  ('bd', 5),
#  ('extern', 5),
#  ('china', 5),
#  ('csr', 5),
#  ('launch', 5),
#  ('participant', 5),
#  ('evaluation', 5),
#  ('accelerator', 5),
#  ('blockchain', 5),
#  ('based', 5),
#  ('next', 5),
#  ('army', 5),
#  ('sub', 5),
#  ('stage', 5),
#  ('com', 5),
#  ('switzerland', 5),
#  ('supervisory', 5),
#  ('artificial', 5),
#  ('northern', 5),
#  ('lieutenant', 5),
#  ('category', 5),
#  ('small', 5),
#  ('partnership', 5),
#  ('eir', 5),
#  ('purchasing', 5),
#  ('value', 5),
#  ('2019', 5),
#  ('ai', 5),
#  ('united', 5),
#  ('liaison', 5),
#  ('governor', 5),
#  ('sciences', 5),
#  ('initiatives', 5),
#  ('environment', 5),
#  ('out', 5),
#  ('1', 5),
#  ('off', 5),
#  ('improvement', 5),
#  ('hiring', 5),
#  ('brokerage', 5),
#  ('ibd', 5),
#  ('operational', 5),
#  ('york', 5),
#  ('other', 5),
#  ('control', 5),
#  ('contributing', 5),
#  ('application', 5),
#  ('transport', 5),
#  ('delegation', 5),
#  ('compliance', 5),
#  ('cco', 5),
#  ('exit', 5),
#  ('payments', 5),
#  ('short', 5),
#  ('eu', 5),
#  ('madrid', 5),
#  ('responsible', 5),
#  ('france', 5),
#  ('scaling', 5),
#  ('year', 5),
#  ('origination', 5),
#  ('competitive', 5),
#  ('modelling', 5),
#  ('world', 5),
#  ('30', 5),
#  ('negotiator', 5),
#  ('art', 5),
#  ('fashion', 5),
#  ('b2c', 5),
#  ('centre', 5),
#  ('commission', 5),
#  ('financing', 5),
#  ('forum', 5),
#  ('site', 5),
#  ('commercialization', 5),
#  ('harvard', 5),
#  ('unity', 5),
#  ('then', 5),
#  ('apac', 5),
#  ('jumia', 5),
#  ('laboratory', 5),
#  ('x', 5),
#  ('branch', 4),
#  ('insight', 4),
#  ('success', 4),
#  ('operation', 4),
#  ('youth', 4),
#  ('b', 4),
#  ('urban', 4),
#  ('responsibility', 4),
#  ('entertainment', 4),
#  ('secretariat', 4),
#  ('competition', 4),
#  ('feature', 4),
#  ('dr', 4),
#  ('controlling', 4),
#  ('worker', 4),
#  ('initiative', 4),
#  ('store', 4),
#  ('merger', 4),
#  ('gmbh', 4),
#  ('with', 4),
#  ('exited', 4),
#  ('sponsor', 4),
#  ('blogger', 4),
#  ('education', 4),
#  ('un', 4),
#  ('ibm', 4),
#  ('interest', 4),
#  ('athlete', 4),
#  ('nations', 4),
#  ('association', 4),
#  ('people', 4),
#  ('home', 4),
#  ('ops', 4),
#  ('cycle', 4),
#  ('crm', 4),
#  ('2', 4),
#  ('lending', 4),
#  ('channel', 4),
#  ('otc', 4),
#  ('o', 4),
#  ('channels', 4),
#  ('hair', 4),
#  ('techstars', 4),
#  ('funds', 4),
#  ('manufacturing', 4),
#  ('valuations', 4),
#  ('permanent', 4),
#  ('mission', 4),
#  ('associated', 4),
#  ('creation', 4),
#  ('delivery', 4),
#  ('military', 4),
#  ('telenor', 4),
#  ('programmes', 4),
#  ('chartered', 4),
#  ('claims', 4),
#  ('uhnw', 4),
#  ('trainer', 4),
#  ('cross', 4),
#  ('organization', 4),
#  ('entrepreneurs', 4),
#  ('presence', 4),
#  ('0', 4),
#  ('press', 4),
#  ('full', 4),
#  ('microfinance', 4),
#  ('applications', 4),
#  ('air', 4),
#  ('primary', 4),
#  ('maker', 4),
#  ('masters', 4),
#  ('concept', 4),
#  ('under', 4),
#  ('wholesale', 4),
#  ('students', 4),
#  ('model', 4),
#  ('shadow', 4),
#  ('distressed', 4),
#  ('strategies', 4),
#  ('cash', 4),
#  ('implementation', 4),
#  ('language', 4),
#  ('mp', 4),
#  ('right', 4),
#  ('salesman', 4),
#  ('state', 4),
#  ('rugby', 4),
#  ('technician', 4),
#  ('postdoctoral', 4),
#  ('class', 4),
#  ('admin', 4),
#  ('epic', 4),
#  ('college', 4),
#  ('regulatory', 4),
#  ('deck', 4),
#  ('john', 4),
#  ('panel', 4),
#  ('hustler', 4),
#  ('as', 4),
#  ('david', 4),
#  ('ophthalmologist', 4),
#  ('registrar', 4),
#  ('hotel', 4),
#  ('turned', 4),
#  ('ads', 4),
#  ('interaction', 4),
#  ('climate', 4),
#  ('front', 4),
#  ('honorary', 4),
#  ('natural', 4),
#  ('rocket', 4),
#  ('lbo', 4),
#  ('leisure', 4),
#  ('staffer', 4),
#  ('helper', 4),
#  ('fd', 4),
#  ('libon', 4),
#  ('skydiver', 4),
#  ('ignite', 4),
#  ('8', 4),
#  ('cis', 3),
#  ('chairwoman', 3),
#  ('women', 3),
#  ('psychologist', 3),
#  ('universal', 3),
#  ('civil', 3),
#  ('backed', 3),
#  ('p', 3),
#  ('show', 3),
#  ('tennis', 3),
#  ('environmental', 3),
#  ('situations', 3),
#  ('position', 3),
#  ('counselor', 3),
#  ('captain', 3),
#  ('privacy', 3),
#  ('omnichannel', 3),
#  ('parliamentary', 3),
#  ('lse', 3),
#  ('ordinator', 3),
#  ('restructuring', 3),
#  ('shaper', 3),
#  ('c', 3),
#  ('level', 3),
#  ('cbo', 3),
#  ('allianz', 3),
#  ('solution', 3),
#  ('germany', 3),
#  ('big', 3),
#  ('sabbatical', 3),
#  ('japan', 3),
#  ('mid', 3),
#  ('distinction', 3),
#  ('t', 3),
#  ('competitiveness', 3),
#  ('ltd', 3),
#  ('rep', 3),
#  ('actuarial', 3),
#  ('platforms', 3),
#  ('oil', 3),
#  ('rate', 3),
#  ('yc', 3),
#  ('intergovernmental', 3),
#  ('facilitator', 3),
#  ('wireless', 3),
#  ('roll', 3),
#  ('sergeant', 3),
#  ('membership', 3),
#  ('profit', 3),
#  ('local', 3),
#  ('org', 3),
#  ('server', 3),
#  ('we', 3),
#  ('re', 3),
#  ('clearing', 3),
#  ('liquidity', 3),
#  ('interpreter', 3),
#  ('tour', 3),
#  ('hong', 3),
#  ('kong', 3),
#  ('surgical', 3),
#  ('weapons', 3),
#  ('saudi', 3),
#  ('solar', 3),
#  ('alternative', 3),
#  ('brands', 3),
#  ('writing', 3),
#  ('companies', 3),
#  ('export', 3),
#  ('diplomacy', 3),
#  ('organising', 3),
#  ('legislative', 3),
#  ('smart', 3),
#  ('mobility', 3),
#  ('waiter', 3),
#  ('agriculture', 3),
#  ('treasurer', 3),
#  ('do', 3),
#  ('case', 3),
#  ('joint', 3),
#  ('seminar', 3),
#  ('applied', 3),
#  ('winner', 3),
#  ('contact', 3),
#  ('italy', 3),
#  ('curriculum', 3),
#  ('commissioner', 3),
#  ('l', 3),
#  ('city', 3),
#  ('jack', 3),
#  ('countries', 3),
#  ('speech', 3),
#  ('3', 3),
#  ('integrated', 3),
#  ('lines', 3),
#  ('creator', 3),
#  ('games', 3),
#  ('arbitrage', 3),
#  ('protection', 3),
#  ('peacebuilding', 3),
#  ('startups', 3),
#  ('direct', 3),
#  ('secondment', 3),
#  ('one', 3),
#  ('spokesperson', 3),
#  ('ef', 3),
#  ('outreach', 3),
#  ('now', 3),
#  ('structure', 3),
#  ('artist', 3),
#  ('exec', 3),
#  ('apprentice', 3),
#  ('avp', 3),
#  ('ib', 3),
#  ('organiser', 3),
#  ('australia', 3),
#  ('aerospace', 3),
#  ('defence', 3),
#  ('ficc', 3),
#  ('launching', 3),
#  ('western', 3),
#  ('southeast', 3),
#  ('congressional', 3),
#  ('contractor', 3),
#  ('rt', 3),
#  ('hon', 3),
#  ('veterinary', 3),
#  ('surgeon', 3),
#  ('loyalty', 3),
#  ('sap', 3),
#  ('underwriter', 3),
#  ('structurer', 3),
#  ('overseas', 3),
#  ('chairperson', 3),
#  ('smb', 3),
#  ('union', 3),
#  ('crew', 3),
#  ('eemea', 3),
#  ('knowledge', 3),
#  ('statistics', 3),
#  ('gap', 3),
#  ('construction', 3),
#  ('connections', 3),
#  ('op', 3),
#  ('senator', 3),
#  ('americas', 3),
#  ('suave', 3),
#  ('water', 3),
#  ('sue', 3),
#  ('myrick', 3),
#  ('conference', 3),
#  ('civic', 3),
#  ('grant', 3),
#  ('automation', 3),
#  ('behavioral', 3),
#  ('positions', 3),
#  ('rights', 3),
#  ('hub', 3),
#  ('entrepreneurial', 3),
#  ('good', 3),
#  ('specialty', 3),
#  ('launcher', 3),
#  ('saharan', 3),
#  ('gaming', 3),
#  ('builder', 3),
#  ('crypto', 3),
#  ('game', 3),
#  ('gp', 3),
#  ('citizenship', 3),
#  ('employment', 3),
#  ('buyer', 3),
#  ('green', 3),
#  ('voice', 3),
#  ('judicial', 3),
#  ('excellence', 3),
#  ('arm', 3),
#  ('court', 3),
#  ('paris', 3),
#  ('summit', 3),
#  ('retention', 3),
#  ('sw', 3),
#  ('macro', 3),
#  ('demonstrator', 3),
#  ('snorkel', 3),
#  ('scuba', 3),
#  ('hnw', 3),
#  ('startupbootcamp', 3),
#  ('yuup', 3),
#  ('futurist', 3),
#  ('anthropologist', 3),
#  ('storyteller', 3),
#  ('auxiliary', 3),
#  ('police', 3),
#  ('cti', 3),
#  ('mirada', 3),
#  ('geffen', 3),
#  ('csmo', 2),
#  ('labs', 2),
#  ('internally', 2),
#  ('premier', 2),
#  ('rse', 2),
#  ('sloan', 2),
#  ('bootcamp', 2),
#  ('brazil', 2),
#  ('labour', 2),
#  ('v', 2),
#  ('du', 2),
#  ('businesses', 2),
#  ('opportunities', 2),
#  ('hc', 2),
#  ('crisis', 2),
#  ('narrative', 2),
#  ('dpt', 2),
#  ('sourcing', 2),
#  ('maskota', 2),
#  ('retargeting', 2),
#  ('sheet14', 2),
#  ('intellectual', 2),
#  ('german', 2),
#  ('incoming', 2),
#  ('freelancer', 2),
#  ('methods', 2),
#  ('pampers', 2),
#  ('ceemea', 2),
#  ('anti', 2),
#  ('blog', 2),
#  ('bosch', 2),
#  ('simmons', 2),
#  ('festival', 2),
#  ('vienna', 2),
#  ('chamber', 2),
#  ('cluster', 2),
#  ('journalism', 2),
#  ('report', 2),
#  ('driven', 2),
#  ('smes', 2),
#  ('sme', 2),
#  ('educator', 2),
#  ('briefing', 2),
#  ('deployment', 2),
#  ('chase', 2),
#  ('manhattan', 2),
#  ('investors', 2),
#  ('powerbar', 2),
#  ('antitrust', 2),
#  ('monetization', 2),
#  ('evangelist', 2),
#  ('patent', 2),
#  ('directorate', 2),
#  ('vision', 2),
#  ('autopilot', 2),
#  ('sirius', 2),
#  ('afghanistan', 2),
#  ('pakistan', 2),
#  ('visa', 2),
#  ('rotational', 2),
#  ('term', 2),
#  ('w', 2),
#  ('chef', 2),
#  ('gilt', 2),
#  ('taste', 2),
#  ('restaurant', 2),
#  ('promoter', 2),
#  ('limited', 2),
#  ('lp', 2),
#  ('composer', 2),
#  ('fulbright', 2),
#  ('apple', 2),
#  ('email', 2),
#  ('windows', 2),
#  ('computing', 2),
#  ('cro', 2),
#  ('dev', 2),
#  ('circulation', 2),
#  ('hacker', 2),
#  ('levant', 2),
#  ('f', 2),
#  ('servicing', 2),
#  ('mining', 2),
#  ('structuring', 2),
#  ('clients', 2),
#  ('korean', 2),
#  ('vip', 2),
#  ('marketplace', 2),
#  ('assessment', 2),
#  ('internships', 2),
#  ('jobs', 2),
#  ('chemicals', 2),
#  ('renewables', 2),
#  ('pe', 2),
#  ('broker', 2),
#  ('nordic', 2),
#  ('g', 2),
#  ('interactive', 2),
#  ('story', 2),
#  ('qotuf', 2),
#  ('pmo', 2),
#  ('esl', 2),
#  ('5', 2),
#  ('barclays', 2),
#  ('commissioned', 2),
#  ('politics', 2),
#  ('bonds', 2),
#  ('mercedes', 2),
#  ('benz', 2),
#  ('singapore', 2),
#  ...]

# %%
#Creat a dictionary

structure = {
    'level 0': ['intern', 'trainee', 'graduate', 'volunteer', 'student', 'candidate'],
    'level 1': ['staff', 'assistant', 'analyst', 'junior', 'fellow', 'reseller','coordinator', 'member', 'sales', 'trader', 'investor', 'developer', 'editor', 'designer', 'producer', 'banker', 'journalist', 'reporter', 'writer', 'auditor', 'clerk', 'blogger', 'artist', 'employee', 'starter', 'bellman', 'waiter', 'kitchen-hand', 'waitress', 'telemarketer', 'filler', 'runner', 'handyman'],
    'level 2': ['senior', 'consultant', 'specialist', 'advisor', 'associate', 'lead', 'leader', 'mentor', 'coach', 'expert', 'economist', 'trainer', 'engineer', 'researcher', 'scientist', 'lecturer', 'tutor', 'teacher', 'lawyer', 'adviser', 'organizer', 'solicitor', 'curator', 'operator', 'architect', 'representative', 'accountant', 'attorney', 'host', 'speaker', 'counsel', 'recruiter', 'creator', 'translator', 'contracted', 'broker', 'analytics', 'publicist', 'presenter'],
    'level 3': ['manager', 'supervisor', 'ambassador', 'strategist', 'instructor', 'administrator', 'professor', 'minister', 'commander', 'officer', 'lieutenant', 'captain', 'jumpmaster', 'handler','manger', 'superintendent', 'store', 'dir','executive', 'anchor', 'shareholder'],
    'level 4': ['director', 'senior manager', 'head', 'vice president', 'executive director', 'controller', 'officer', 'dir'],
    'level 5': ['partner', 'owner', 'chief', 'ceo', 'coo', 'cfo', 'cto', 'president', 'principal', 'entrepreneur', 'co-founder', 'founder', 'board member', 'chairman', 'co-owner', 'chair', 'governor', 'chro', 'chef', 'mp', 'exec', 'cco']
}


flat_structure = {title: level for level, titles in structure.items() for title in titles}
flat_structure
# Out:
# {'intern': 'level 0',
#  'trainee': 'level 0',
#  'graduate': 'level 0',
#  'volunteer': 'level 0',
#  'student': 'level 0',
#  'candidate': 'level 0',
#  'staff': 'level 1',
#  'assistant': 'level 1',
#  'analyst': 'level 1',
#  'junior': 'level 1',
#  'fellow': 'level 1',
#  'reseller': 'level 1',
#  'coordinator': 'level 1',
#  'member': 'level 1',
#  'sales': 'level 1',
#  'trader': 'level 1',
#  'investor': 'level 1',
#  'developer': 'level 1',
#  'editor': 'level 1',
#  'designer': 'level 1',
#  'producer': 'level 1',
#  'banker': 'level 1',
#  'journalist': 'level 1',
#  'reporter': 'level 1',
#  'writer': 'level 1',
#  'auditor': 'level 1',
#  'clerk': 'level 1',
#  'blogger': 'level 1',
#  'artist': 'level 1',
#  'employee': 'level 1',
#  'starter': 'level 1',
#  'bellman': 'level 1',
#  'waiter': 'level 1',
#  'kitchen-hand': 'level 1',
#  'waitress': 'level 1',
#  'telemarketer': 'level 1',
#  'filler': 'level 1',
#  'runner': 'level 1',
#  'handyman': 'level 1',
#  'senior': 'level 2',
#  'consultant': 'level 2',
#  'specialist': 'level 2',
#  'advisor': 'level 2',
#  'associate': 'level 2',
#  'lead': 'level 2',
#  'leader': 'level 2',
#  'mentor': 'level 2',
#  'coach': 'level 2',
#  'expert': 'level 2',
#  'economist': 'level 2',
#  'trainer': 'level 2',
#  'engineer': 'level 2',
#  'researcher': 'level 2',
#  'scientist': 'level 2',
#  'lecturer': 'level 2',
#  'tutor': 'level 2',
#  'teacher': 'level 2',
#  'lawyer': 'level 2',
#  'adviser': 'level 2',
#  'organizer': 'level 2',
#  'solicitor': 'level 2',
#  'curator': 'level 2',
#  'operator': 'level 2',
#  'architect': 'level 2',
#  'representative': 'level 2',
#  'accountant': 'level 2',
#  'attorney': 'level 2',
#  'host': 'level 2',
#  'speaker': 'level 2',
#  'counsel': 'level 2',
#  'recruiter': 'level 2',
#  'creator': 'level 2',
#  'translator': 'level 2',
#  'contracted': 'level 2',
#  'broker': 'level 2',
#  'analytics': 'level 2',
#  'publicist': 'level 2',
#  'presenter': 'level 2',
#  'manager': 'level 3',
#  'supervisor': 'level 3',
#  'ambassador': 'level 3',
#  'strategist': 'level 3',
#  'instructor': 'level 3',
#  'administrator': 'level 3',
#  'professor': 'level 3',
#  'minister': 'level 3',
#  'commander': 'level 3',
#  'officer': 'level 4',
#  'lieutenant': 'level 3',
#  'captain': 'level 3',
#  'jumpmaster': 'level 3',
#  'handler': 'level 3',
#  'manger': 'level 3',
#  'superintendent': 'level 3',
#  'store': 'level 3',
#  'dir': 'level 4',
#  'executive': 'level 3',
#  'anchor': 'level 3',
#  'shareholder': 'level 3',
#  'director': 'level 4',
#  'senior manager': 'level 4',
#  'head': 'level 4',
#  'vice president': 'level 4',
#  'executive director': 'level 4',
#  'controller': 'level 4',
#  'partner': 'level 5',
#  'owner': 'level 5',
#  'chief': 'level 5',
#  'ceo': 'level 5',
#  'coo': 'level 5',
#  'cfo': 'level 5',
#  'cto': 'level 5',
#  'president': 'level 5',
#  'principal': 'level 5',
#  'entrepreneur': 'level 5',
#  'co-founder': 'level 5',
#  'founder': 'level 5',
#  'board member': 'level 5',
#  'chairman': 'level 5',
#  'co-owner': 'level 5',
#  'chair': 'level 5',
#  'governor': 'level 5',
#  'chro': 'level 5',
#  'chef': 'level 5',
#  'mp': 'level 5',
#  'exec': 'level 5',
#  'cco': 'level 5'}

# %%
priority_structure = [
    ('level 1', structure['level 1']),
    ('level 2', structure['level 2']),
    ('level 3', structure['level 3']),
    ('level 4', structure['level 4']),
    ('level 5', structure['level 5'])
]

def get_level_priority(title):
    if isinstance(title, str):
        for level, titles in priority_structure:
            for key in titles:
                if key in title:
                    return int(level.split()[1])
    return np.nan

# %%
# Allocate the level
career['Level'] = career['JobTitle'].apply(get_level_priority)

# %% [markdown]
# ### Calculate Speed of Growth

# %%
import numpy as np

# %%
# Deal with null value
for i in range(1, len(career)):
    if np.isnan(career.loc[i, 'Level']):
        if career.loc[i, 'FounderID'] == career.loc[i-1, 'FounderID'] and career.loc[i, 'CompanyID'] == career.loc[i-1, 'CompanyID']:
            career.loc[i, 'Level'] = career.loc[i-1, 'Level'] + 1
        else:
            career.loc[i, 'Level'] = career.loc[i-1, 'Level']

for i in range(len(career)-2, -1, -1):
    if np.isnan(career.loc[i, 'Level']):
        if career.loc[i, 'FounderID'] == career.loc[i+1, 'FounderID'] and career.loc[i, 'CompanyID'] == career.loc[i+1, 'CompanyID']:
            career.loc[i, 'Level'] = career.loc[i+1, 'Level'] - 1
        else:
            career.loc[i, 'Level'] = career.loc[i+1, 'Level']
career
# Out:
#        CareerID  FounderID  CompanyID  \
# 0             8          1      53036
# 1             7          1      53036
# 2        216950          1      19921
# 3         80467          3      27310
# 4         80414          3      39824
# ...         ...        ...        ...
# 11331    238807      25746     127266
# 11332    312809      25746     152402
# 11333    238804      25746     127266
# 11334    312807      25746     152400
# 11335    238800      25746     127266
#
#                                            JobTitle          DateRange  \
# 0                                    vice president          2005–2009
# 1                                executive director          2007–2009
# 2                                           founder    01/2016-Present
# 3                                   lead accountant  Nov 2001–Apr 2006
# 4      manager of finance and accounting cis region  May 2006–Oct 2008
# ...                                             ...                ...
# 11331            chief technical officer co founder    10/2015-12/2017
# 11332                            product strategist      1/2017-9/2018
# 11333              chief product officer co founder    12/2017-01/2019
# 11334            chief executive officer co founder     12/2018-3/2021
# 11335                                       advisor    01/2019-12/2019
#
#        Start Date    End Date  Duration (years)                    Location  \
# 0      2005-03-01  2009-09-01               4.5                         NaN
# 1      2007-03-01  2009-09-01               2.5  Moscow, Russian Federation
# 2      2016-01-01         NaN               6.4                      Cyprus
# 3      2001-11-01  2006-04-01               4.4                         NaN
# 4      2006-05-01  2008-10-01               2.4                         NaN
# ...           ...         ...               ...                         ...
# 11331  2015-10-01  2017-12-01               2.2        Toronto, Canada Area
# 11332  2017-01-01  2018-09-01               1.7                         NaN
# 11333  2017-12-01  2019-01-01               1.1        Toronto, Canada Area
# 11334  2018-12-01  2021-03-01               2.2                         NaN
# 11335  2019-01-01  2019-12-01               0.9                         NaN
#
#                                              Description Created Date  \
# 0                                                    NaN   2021-02-19
# 1                                                    NaN   2021-02-19
# 2      We are the largest global \ntravel mobility ma...   2022-05-05
# 3                                                    NaN   2021-03-10
# 4                                                    NaN   2021-03-10
# ...                                                  ...          ...
# 11331                                                NaN   2022-06-17
# 11332                                                NaN   2023-03-29
# 11333                                                NaN   2022-06-17
# 11334  Inkblot was acquired by Green Shield Holdings ...   2023-03-29
# 11335                                                NaN   2022-06-17
#
#        Relevant  founded_company_value Headquarters Location  \
# 0         False                    NaN                   NaN
# 1         False                    NaN                   NaN
# 2          True             22450000.0   European Union (EU)
# 3         False                    NaN                   NaN
# 4         False                    NaN                   NaN
# ...         ...                    ...                   ...
# 11331      True             12500000.0      Toronto, Ontario
# 11332     False                    NaN                   NaN
# 11333      True             12500000.0      Toronto, Ontario
# 11334      True              3808640.0                   NaN
# 11335     False             12500000.0      Toronto, Ontario
#
#       Number Of Employees  index  Level
# 0                     NaN      0    4.0
# 1                     NaN      1    3.0
# 2                     NaN      2    5.0
# 3                     NaN      0    2.0
# 4                     NaN      1    3.0
# ...                   ...    ...    ...
# 11331               11-50      4    3.0
# 11332                 NaN      5    3.0
# 11333               11-50      6    3.0
# 11334                 NaN      7    3.0
# 11335               11-50      8    2.0
#
# [11336 rows x 17 columns]

# %%
# Calculate difference
career['diff'] = np.nan

for i in range(1, len(career)):
    if i == 0:
        career.loc[i, 'diff'] = np.nan
    else:
        diff = career.loc[i, 'Level'] - career.loc[i-1, 'Level']
        if diff < 0:
            if career.loc[i, 'CompanyID'] == career.loc[i-1, 'CompanyID']:
                career.loc[i, 'diff'] = 1
            else:
                career.loc[i, 'diff'] = 0
        else:
            career.loc[i, 'diff'] = diff

career
# Out:
#        CareerID  FounderID  CompanyID  \
# 0             8          1      53036
# 1             7          1      53036
# 2        216950          1      19921
# 3         80467          3      27310
# 4         80414          3      39824
# ...         ...        ...        ...
# 11331    238807      25746     127266
# 11332    312809      25746     152402
# 11333    238804      25746     127266
# 11334    312807      25746     152400
# 11335    238800      25746     127266
#
#                                            JobTitle          DateRange  \
# 0                                    vice president          2005–2009
# 1                                executive director          2007–2009
# 2                                           founder    01/2016-Present
# 3                                   lead accountant  Nov 2001–Apr 2006
# 4      manager of finance and accounting cis region  May 2006–Oct 2008
# ...                                             ...                ...
# 11331            chief technical officer co founder    10/2015-12/2017
# 11332                            product strategist      1/2017-9/2018
# 11333              chief product officer co founder    12/2017-01/2019
# 11334            chief executive officer co founder     12/2018-3/2021
# 11335                                       advisor    01/2019-12/2019
#
#        Start Date    End Date  Duration (years)                    Location  \
# 0      2005-03-01  2009-09-01               4.5                         NaN
# 1      2007-03-01  2009-09-01               2.5  Moscow, Russian Federation
# 2      2016-01-01         NaN               6.4                      Cyprus
# 3      2001-11-01  2006-04-01               4.4                         NaN
# 4      2006-05-01  2008-10-01               2.4                         NaN
# ...           ...         ...               ...                         ...
# 11331  2015-10-01  2017-12-01               2.2        Toronto, Canada Area
# 11332  2017-01-01  2018-09-01               1.7                         NaN
# 11333  2017-12-01  2019-01-01               1.1        Toronto, Canada Area
# 11334  2018-12-01  2021-03-01               2.2                         NaN
# 11335  2019-01-01  2019-12-01               0.9                         NaN
#
#                                              Description Created Date  \
# 0                                                    NaN   2021-02-19
# 1                                                    NaN   2021-02-19
# 2      We are the largest global \ntravel mobility ma...   2022-05-05
# 3                                                    NaN   2021-03-10
# 4                                                    NaN   2021-03-10
# ...                                                  ...          ...
# 11331                                                NaN   2022-06-17
# 11332                                                NaN   2023-03-29
# 11333                                                NaN   2022-06-17
# 11334  Inkblot was acquired by Green Shield Holdings ...   2023-03-29
# 11335                                                NaN   2022-06-17
#
#        Relevant  founded_company_value Headquarters Location  \
# 0         False                    NaN                   NaN
# 1         False                    NaN                   NaN
# 2          True             22450000.0   European Union (EU)
# 3         False                    NaN                   NaN
# 4         False                    NaN                   NaN
# ...         ...                    ...                   ...
# 11331      True             12500000.0      Toronto, Ontario
# 11332     False                    NaN                   NaN
# 11333      True             12500000.0      Toronto, Ontario
# 11334      True              3808640.0                   NaN
# 11335     False             12500000.0      Toronto, Ontario
#
#       Number Of Employees  index  Level  diff
# 0                     NaN      0    4.0   NaN
# 1                     NaN      1    3.0   1.0
# 2                     NaN      2    5.0   2.0
# 3                     NaN      0    2.0   0.0
# 4                     NaN      1    3.0   1.0
# ...                   ...    ...    ...   ...
# 11331               11-50      4    3.0   0.0
# 11332                 NaN      5    3.0   0.0
# 11333               11-50      6    3.0   0.0
# 11334                 NaN      7    3.0   0.0
# 11335               11-50      8    2.0   0.0
#
# [11336 rows x 18 columns]

# %%
# Calculate speed
career['Speed'] = np.nan

for i in range(1, len(career)):
    if not np.isnan(career.loc[i, 'diff']):
        career.loc[i, 'Speed'] = career.loc[i, 'diff'] / career.loc[i-1, 'Duration (years)']
career['Speed'].replace(np.inf, 0, inplace=True)
# Out:
# <ipython-input-24-05d874ba9511>:6: RuntimeWarning: invalid value encountered in scalar divide
#   df.loc[i, 'Speed'] = df.loc[i, 'diff'] / df.loc[i-1, 'Duration (years)']
# <ipython-input-24-05d874ba9511>:6: RuntimeWarning: divide by zero encountered in scalar divide
#   df.loc[i, 'Speed'] = df.loc[i, 'diff'] / df.loc[i-1, 'Duration (years)']

# %%
# Add new index
index_new = []
counter = 0

for i in career['index']:
    if i == 0:
        counter += 1
    index_new.append(counter)

career['index_new'] = index_new
career
# Out:
#        CareerID  FounderID  CompanyID  \
# 0             8          1      53036
# 1             7          1      53036
# 2        216950          1      19921
# 3         80467          3      27310
# 4         80414          3      39824
# ...         ...        ...        ...
# 11331    238807      25746     127266
# 11332    312809      25746     152402
# 11333    238804      25746     127266
# 11334    312807      25746     152400
# 11335    238800      25746     127266
#
#                                            JobTitle          DateRange  \
# 0                                    vice president          2005–2009
# 1                                executive director          2007–2009
# 2                                           founder    01/2016-Present
# 3                                   lead accountant  Nov 2001–Apr 2006
# 4      manager of finance and accounting cis region  May 2006–Oct 2008
# ...                                             ...                ...
# 11331            chief technical officer co founder    10/2015-12/2017
# 11332                            product strategist      1/2017-9/2018
# 11333              chief product officer co founder    12/2017-01/2019
# 11334            chief executive officer co founder     12/2018-3/2021
# 11335                                       advisor    01/2019-12/2019
#
#        Start Date    End Date  Duration (years)                    Location  \
# 0      2005-03-01  2009-09-01               4.5                         NaN
# 1      2007-03-01  2009-09-01               2.5  Moscow, Russian Federation
# 2      2016-01-01         NaN               6.4                      Cyprus
# 3      2001-11-01  2006-04-01               4.4                         NaN
# 4      2006-05-01  2008-10-01               2.4                         NaN
# ...           ...         ...               ...                         ...
# 11331  2015-10-01  2017-12-01               2.2        Toronto, Canada Area
# 11332  2017-01-01  2018-09-01               1.7                         NaN
# 11333  2017-12-01  2019-01-01               1.1        Toronto, Canada Area
# 11334  2018-12-01  2021-03-01               2.2                         NaN
# 11335  2019-01-01  2019-12-01               0.9                         NaN
#
#                                              Description Created Date  \
# 0                                                    NaN   2021-02-19
# 1                                                    NaN   2021-02-19
# 2      We are the largest global \ntravel mobility ma...   2022-05-05
# 3                                                    NaN   2021-03-10
# 4                                                    NaN   2021-03-10
# ...                                                  ...          ...
# 11331                                                NaN   2022-06-17
# 11332                                                NaN   2023-03-29
# 11333                                                NaN   2022-06-17
# 11334  Inkblot was acquired by Green Shield Holdings ...   2023-03-29
# 11335                                                NaN   2022-06-17
#
#        Relevant  founded_company_value Headquarters Location  \
# 0         False                    NaN                   NaN
# 1         False                    NaN                   NaN
# 2          True             22450000.0   European Union (EU)
# 3         False                    NaN                   NaN
# 4         False                    NaN                   NaN
# ...         ...                    ...                   ...
# 11331      True             12500000.0      Toronto, Ontario
# 11332     False                    NaN                   NaN
# 11333      True             12500000.0      Toronto, Ontario
# 11334      True              3808640.0                   NaN
# 11335     False             12500000.0      Toronto, Ontario
#
#       Number Of Employees  index  Level  diff     Speed  index_new
# 0                     NaN      0    4.0   NaN       NaN          1
# 1                     NaN      1    3.0   1.0  0.222222          1
# 2                     NaN      2    5.0   2.0  0.800000          1
# 3                     NaN      0    2.0   0.0  0.000000          2
# 4                     NaN      1    3.0   1.0  0.227273          2
# ...                   ...    ...    ...   ...       ...        ...
# 11331               11-50      4    3.0   0.0  0.000000       1823
# 11332                 NaN      5    3.0   0.0  0.000000       1823
# 11333               11-50      6    3.0   0.0  0.000000       1823
# 11334                 NaN      7    3.0   0.0  0.000000       1823
# 11335               11-50      8    2.0   0.0  0.000000       1823
#
# [11336 rows x 20 columns]

# %%
career['Speed_sum'] = np.nan
career['Count'] = np.nan

# Initialize the variables
count = 0
speed_sum = 0

# Iterate through the data
for i in range(1, len(career)):
    if career['index'].iloc[i] == 0:
        career.loc[i-1, 'Speed_sum'] = speed_sum
        career.loc[i-1, 'Count'] = count
        count = 0
        speed_sum = 0
    else:
        count += 1
        speed_sum += career['Speed'].iloc[i]

# The value of the last group
career.loc[len(career)-1, 'Speed_sum'] = speed_sum
career.loc[len(career)-1, 'Count'] = count
career
# Out:
#        CareerID  FounderID  CompanyID  \
# 0             8          1      53036
# 1             7          1      53036
# 2        216950          1      19921
# 3         80467          3      27310
# 4         80414          3      39824
# ...         ...        ...        ...
# 11331    238807      25746     127266
# 11332    312809      25746     152402
# 11333    238804      25746     127266
# 11334    312807      25746     152400
# 11335    238800      25746     127266
#
#                                            JobTitle          DateRange  \
# 0                                    vice president          2005–2009
# 1                                executive director          2007–2009
# 2                                           founder    01/2016-Present
# 3                                   lead accountant  Nov 2001–Apr 2006
# 4      manager of finance and accounting cis region  May 2006–Oct 2008
# ...                                             ...                ...
# 11331            chief technical officer co founder    10/2015-12/2017
# 11332                            product strategist      1/2017-9/2018
# 11333              chief product officer co founder    12/2017-01/2019
# 11334            chief executive officer co founder     12/2018-3/2021
# 11335                                       advisor    01/2019-12/2019
#
#        Start Date    End Date  Duration (years)                    Location  \
# 0      2005-03-01  2009-09-01               4.5                         NaN
# 1      2007-03-01  2009-09-01               2.5  Moscow, Russian Federation
# 2      2016-01-01         NaN               6.4                      Cyprus
# 3      2001-11-01  2006-04-01               4.4                         NaN
# 4      2006-05-01  2008-10-01               2.4                         NaN
# ...           ...         ...               ...                         ...
# 11331  2015-10-01  2017-12-01               2.2        Toronto, Canada Area
# 11332  2017-01-01  2018-09-01               1.7                         NaN
# 11333  2017-12-01  2019-01-01               1.1        Toronto, Canada Area
# 11334  2018-12-01  2021-03-01               2.2                         NaN
# 11335  2019-01-01  2019-12-01               0.9                         NaN
#
#                                              Description  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2      We are the largest global \ntravel mobility ma...  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 11331                                                NaN  ...
# 11332                                                NaN  ...
# 11333                                                NaN  ...
# 11334  Inkblot was acquired by Green Shield Holdings ...  ...
# 11335                                                NaN  ...
#
#       founded_company_value  Headquarters Location  Number Of Employees index  \
# 0                       NaN                    NaN                  NaN     0
# 1                       NaN                    NaN                  NaN     1
# 2                22450000.0    European Union (EU)                  NaN     2
# 3                       NaN                    NaN                  NaN     0
# 4                       NaN                    NaN                  NaN     1
# ...                     ...                    ...                  ...   ...
# 11331            12500000.0       Toronto, Ontario                11-50     4
# 11332                   NaN                    NaN                  NaN     5
# 11333            12500000.0       Toronto, Ontario                11-50     6
# 11334             3808640.0                    NaN                  NaN     7
# 11335            12500000.0       Toronto, Ontario                11-50     8
#
#       Level  diff     Speed  index_new  Speed_sum  Count
# 0       4.0   NaN       NaN          1        NaN    NaN
# 1       3.0   1.0  0.222222          1        NaN    NaN
# 2       5.0   2.0  0.800000          1   1.022222    2.0
# 3       2.0   0.0  0.000000          2        NaN    NaN
# 4       3.0   1.0  0.227273          2        NaN    NaN
# ...     ...   ...       ...        ...        ...    ...
# 11331   3.0   0.0  0.000000       1823        NaN    NaN
# 11332   3.0   0.0  0.000000       1823        NaN    NaN
# 11333   3.0   0.0  0.000000       1823        NaN    NaN
# 11334   3.0   0.0  0.000000       1823        NaN    NaN
# 11335   2.0   0.0  0.000000       1823   1.923077    8.0
#
# [11336 rows x 22 columns]

# %%
speed_of_growth = career[['CareerID','FounderID','CompanyID','index_new','Speed_sum','Count']]
speed_of_growth = speed_of_growth.dropna(subset=['Count'])

# %%
speed_of_growth['Speed_avg'] = speed_of_growth['Speed_sum'] / speed_of_growth['Count']
speed_of_growth
# Out:
#        CareerID  FounderID  CompanyID  index_new  Speed_sum  Count  Speed_avg
# 2        216950          1      19921          1   1.022222    2.0   0.511111
# 11        79402          3      17160          2   1.366729    8.0   0.170841
# 19           39          6      19921          3   0.865094    7.0   0.123585
# 23          107         13      20739          4   0.731707    3.0   0.243902
# 31          223         28      50729          5   7.515152    7.0   1.073593
# ...         ...        ...        ...        ...        ...    ...        ...
# 11306    258565      25262     121204       1819   0.000000    2.0   0.000000
# 11311    238807      25746     127266       1820   1.923077    4.0   0.480769
# 11318    238804      25746     127266       1821   1.923077    6.0   0.320513
# 11326    312807      25746     152400       1822   1.923077    7.0   0.274725
# 11335    238800      25746     127266       1823   1.923077    8.0   0.240385
#
# [1823 rows x 7 columns]

# %%
final_result_df = final_result_df.merge(speed_of_growth[['CareerID','Speed_avg']], on='CareerID', how='left')

# %% [markdown]
# ## Location relevance

# %% [markdown]
# In this section we want to investigate the relationship between specific locations and the veticals that are most likely to thrive there.

# %% [markdown]
# **Create Location-Vertical Dictionary**
#
#
# By web scraping and manually mapping, we create a dictionary where the key is the location, and the value is their corresponding vertical.
#
# **Remark**: A location can includes many verticals, and a vertical can be belong to many locations.

# %%
import requests
from bs4 import BeautifulSoup

def get_h3_texts_within_h2(city_name, section_id):
    url = f"https://en.wikipedia.org/wiki/{city_name}"
    try:
        response = requests.get(url)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')


        section_header = soup.find('span', id=section_id)
        if not section_header:
            return f"No section found with ID {section_id} in the {city_name} page."


        h2_tag = section_header.find_parent('h2')


        h3_texts = []
        for sibling in h2_tag.find_next_siblings():
            if sibling.name == 'h2':
                break
            if sibling.name == 'h3':
                header_span = sibling.find('span', class_='mw-headline')
                if header_span:
                    h3_texts.append(header_span.text)

        return h3_texts if h3_texts else f"No <h3> tags found within the section {section_id}."

    except requests.HTTPError as e:
        return f"HTTP error occurred: {e}"
    except Exception as e:
        return f"An error occurred: {e}"


cities_example = ['london', 'new york city', 'san francisco', 'berlin', 'paris', 'singapore',
       'washington (state)', 'barcelona', 'los angeles', 'madrid', 'munich',
       'copenhagen', 'mexico', 'milan', 'mumbai', 'boston', 'chicago',
       'stockholm', 'cambridge', 'vienna', 'new delhi', 'brussels', 'zurich',
       'frankfurt', 'Sao Paulo', 'amsterdam', 'toronto', 'oslo', 'hong kong',
       'beijing', 'helsinki', 'dubai', 'moscow', 'istanbul', 'oxford',
       'san diego', 'bengaluru', 'greece', 'shanghai', 'Kuala Lumpur',
       'nairobi', 'united kingdom', 'lisbon', 'philadelphia',
       'Seattle_metropolitan_area', 'montreal', 'sydney', 'gurgaon']
       #The locations in the list have not been cleaned.

section_id = "Economy"
results = {}

for city in cities_example:
    h3_texts = get_h3_texts_within_h2(city, section_id)
    results[city] = h3_texts

print(results)
# Out:
# {'london': ['City of London', 'Media and technology', 'Tourism'], 'new york city': ['Wall Street', 'Tech and biotech', 'Real estate', 'Tourism', 'Media and entertainment'], 'san francisco': ['Technology', 'Tourism and conventions'], 'berlin': ['Companies', 'Tourism and conventions', 'Creative industries', 'Media'], 'paris': ['Employment and income', 'Tourism'], 'singapore': 'No <h3> tags found within the section Economy.', 'washington (state)': ['Taxes', 'Agriculture', 'Wine', 'Military', 'Internet access'], 'barcelona': ['General information', 'Trade fair and exhibitions', 'Tourism', 'Manufacturing sector', 'Fashion'], 'los angeles': 'No <h3> tags found within the section Economy.', 'madrid': ['Economic history', 'Present-day economy', 'Media and entertainment'], 'munich': ['Manufacturing', 'Finance', 'Media'], 'copenhagen': ['Tourism'], 'mexico': ['Communications', 'Energy', 'Science and technology', 'Tourism', 'Transportation'], 'milan': ['Tourism'], 'mumbai': 'No <h3> tags found within the section Economy.', 'boston': 'No <h3> tags found within the section Economy.', 'chicago': 'No <h3> tags found within the section Economy.', 'stockholm': 'No <h3> tags found within the section Economy.', 'cambridge': 'No <h3> tags found within the section Economy.', 'vienna': ['Research and development', 'Information technologies', 'Conferences', 'Tourism'], 'new delhi': 'No <h3> tags found within the section Economy.', 'brussels': 'No <h3> tags found within the section Economy.', 'zurich': ['Contributory factors to economic strength', 'The Swiss stock exchange'], 'frankfurt': 'No section found with ID Economy in the frankfurt page.', 'Sao Paulo': ['Tourism'], 'amsterdam': ['Port of Amsterdam', 'Tourism', 'Retail', 'Fashion'], 'toronto': ['Bay Street', 'Media and entertainment', 'Real estate', 'Technology and biotech', 'Tourism'], 'oslo': 'No <h3> tags found within the section Economy.', 'hong kong': 'No <h3> tags found within the section Economy.', 'beijing': ['Sector composition', 'Economic zones'], 'helsinki': 'No <h3> tags found within the section Economy.', 'dubai': ['Real estate and property', 'Tourism and retail', 'Expo 2020'], 'moscow': ['Overview', 'Industry', 'Cost of living', 'Public utilities'], 'istanbul': 'No <h3> tags found within the section Economy.', 'oxford': ['Car production', 'Publishing', 'Science and technology', 'Education', 'Tourism', 'Retail', 'Brewing', 'Bellfounding'], 'san diego': ['Top employers', 'Defense and military', 'Tourism', 'International trade', 'Companies', 'Real estate'], 'bengaluru': 'No <h3> tags found within the section Economy.', 'greece': ['Debt crisis (2010–2018)', 'Agriculture', 'Energy', 'Maritime', 'Tourism', 'Transport', 'Telecommunications', 'Science and technology'], 'shanghai': ['Finance', 'Manufacturing', 'Tourism', 'Free-trade zone'], 'Kuala Lumpur': ['Tourism', 'Retail'], 'nairobi': ['Central business district and skyline', 'Upper Hill'], 'united kingdom': ['Science and technology', 'Transport', 'Energy', 'Water supply and sanitation'], 'lisbon': 'No <h3> tags found within the section Economy.', 'philadelphia': ['Corporations', 'Tech and biotech', 'Tourism', 'Trade and transportation'], 'Seattle_metropolitan_area': ['Tourism'], 'montreal': 'No <h3> tags found within the section Economy.', 'sydney': ['Businesses', 'Domestic economics', 'Financial services', 'Manufacturing', 'Tourism and international education', 'Housing affordability'], 'gurgaon': 'No <h3> tags found within the section Economy.'}

# %%
verticals_by_location = {
    'london': ['Fintech', 'Cybersecurity', 'Legal tech', 'Adtech, Marketing tech', 'Media and telecommunications (TMT), Technology'],
    'new york': ['Fintech', 'Mortgage tech, Real estate tech', 'Cybersecurity', 'Adtech, Marketing tech', 'Media and telecommunications (TMT), Technology'],
    'san francisco': ['Cybersecurity', 'Cloudtech and DevOps, Software as a service (SaaS)', 'Artificial intelligence and machine learning (AI/ML)', 'Mobile'],
    'berlin': ['Gaming, eSports', 'Digital health, Lifestyles of Health and Sustainability (LOHAS) and wellness, Wearables and quantified self', 'Cleantech'],
    'paris': ['Beauty, Femtech', 'Ecommerce', 'Digital health, Lifestyles of Health and Sustainability (LOHAS) and wellness, Wearables and quantified self'],
    'singapore': ['Fintech', 'Supply chain technology', 'B2B payments, Mobile commerce', 'Insurtech'],
    'washington': ['Cleantech', 'Agtech', 'Space tech'],
    'barcelona': ['Ecommerce', 'Mobile'],
    'los angeles': ['Media and telecommunications (TMT), Technology', 'Audiotech', 'Ecommerce', 'Adtech, Marketing tech'],
    'madrid': ['Mortgage tech, Real estate tech', 'Digital health, Lifestyles of Health and Sustainability (LOHAS) and wellness, Wearables and quantified self'],
    'munich': ['Autonomous cars', '3D printing, Advanced manufacturing, Construction technology, Industrials, Infrastructure, Manufacturing', 'Robotics and drones'],
    'copenhagen': ['Cleantech', 'Digital health, Lifestyles of Health and Sustainability (LOHAS) and wellness, Wearables and quantified self'],
    'mexico': ['Energy', 'Media and telecommunications (TMT), Technology', 'Infrastructure'],
    'milan': ['Beauty, Femtech', 'Ecommerce'],
    'mumbai': ['Ecommerce', 'Media and telecommunications (TMT), Technology', '3D printing, Advanced manufacturing, Construction technology, Industrials, Infrastructure, Manufacturing'],
    'boston': ['Life sciences', 'Edtech', 'Healthtech'],
    'chicago': ['Fintech', 'Foodtech', 'HRtech'],
    'stockholm': ['Cleantech', 'Edtech', 'Digital health, Lifestyles of Health and Sustainability (LOHAS) and wellness, Wearables and quantified self'],
    'cambridge': ['Life sciences', 'Edtech'],
    'vienna': ['Healthtech'],
    'new delhi': ['Fintech', 'Healthtech', 'Edtech'],
    'zurich': ['Fintech', 'Insurtech'],
    'sao paulo': ['Fintech', 'Agtech', 'Ecommerce'],
    'amsterdam': ['Fintech', 'Ecommerce'],
    'toronto': ['Fintech', 'Media and telecommunications (TMT), Technology', 'Edtech'],
    'oslo': ['Oil and gas', 'Energy', 'Space tech'],
    'hong kong': ['Fintech', 'Mortgage tech, Real estate tech', 'Supply chain technology'],
    'beijing': ['Big Data', 'Artificial intelligence and machine learning (AI/ML)', 'Ecommerce'],
    'dubai': ['Mortgage tech, Real estate tech', 'Space tech', 'Ecommerce'],
    'istanbul': ['Foodtech', 'Agtech'],
    'oxford': ['Edtech', 'Life sciences'],
    'san diego': ['Healthtech', 'Life sciences', 'Cybersecurity'],
    'bengaluru': ['Cloudtech and DevOps, Software as a service (SaaS)', 'Space tech', 'Life sciences'],
    'greece': ['Agtech'],
    'kuala lumpur': ['Ecommerce', 'Edtech'],
    'nairobi': ['Agtech', 'Fintech', 'Edtech'],
    'seattle': ['Cloudtech and DevOps, Software as a Service (SaaS)', 'Aerospace', 'Cleantech'],
    'gurgaon': ["Fintech", "Real estate tech", "Automotive tech", "IT and software development", "Cloudtech and DevOps", "Artificial intelligence and machine learning (AI/ML)"],
    'united states': ['Cleantech', 'Cybersecurity', 'Artificial intelligence and machine learning (AI/ML)',  ],
}

# %% [markdown]
# **Get the Possible Predicted Verticals**

# %%
final_result_df['predicted verticals'] = final_result_df['Location'].map(verticals_by_location)

# %%
# Ensure the columns are strings
final_result_df['Vertical'] = final_result_df['Vertical'].astype(str)
final_result_df['predicted verticals'] = final_result_df['predicted verticals'].astype(str)

# Check if 'Location' is in 'predicted location' and assign 1 if true, 0 if false or NaN values
final_result_df['relevance'] = final_result_df.apply(lambda row: 1 if pd.notna(row['Vertical']) and row['Vertical'] != 'nan' and \
                             pd.notna(row['predicted verticals']) and row['Vertical'] in row['predicted verticals'] \
                             else 0, axis=1)

# %%
# Calculate the counts of 1s and 0s in the 'relevance' column
relevance_counts = final_result_df['relevance'].value_counts()

# Print the results
print(relevance_counts)
# Out:
# relevance
# 0    1748
# 1      78
# Name: count, dtype: int64

# %% [markdown]
# ## Consider the founding experience in the team size

# %%
# Group by 'CompanyID' and count the number of unique 'FounderID' for each company
founder_count_per_company = final_result_df.groupby('CompanyID')['FounderID'].count()

# Count the number of companies for each unique founder count and sort by the founder count
founder_distribution = founder_count_per_company.value_counts().sort_index()

print("Founder distribution per company:")
print(founder_distribution)
# Out:
# Founder distribution per company:
# FounderID
# 1    1548
# 2      98
# 3      12
# 4       1
# 5       1
# 6       2
# Name: count, dtype: int64

# %% [markdown]
# By analyzing the number of unique founders per company, we observe that most companies have only one founder. Therefore, we do not consider predicting entrepreneurial success based on team size.

# %% [markdown]
# ## Classify the company to successful categories

# %% [markdown]
# Here we first move the 'Founded Company Value' to the last column. Then, based on the 'Founded Company Value', we classify the companies into binary and multi-level categories of success.

# %%
# Get all column names
columns = list(final_result_df.columns)

# Remove the 'Founded Company Value' column name
columns.remove('Founded Company Value')

# Append 'Founded Company Value' to the end of the column names list
columns.append('Founded Company Value')

# Reindex the DataFrame with the new column order
final_result_df = final_result_df.reindex(columns=columns)
final_result_df.head(5)
# Out:
#    FounderID  CompanyID  CareerID  Number of professional experience  \
# 0          1      19921    216950                                  2
# 1          3      17160     79402                                  8
# 2          6      19921        39                                  7
# 3         13      20739       107                                  3
# 4         28      50729       223                                  7
#
#    Number of companies that worked for  Total Work Years  Industry Experience  \
# 0                                    1               7.0                  0.0
# 1                                    8              31.1                  0.0
# 2                                    6              18.9                  0.0
# 3                                    3               7.1                  0.0
# 4                                    7               7.2                  0.0
#
#    Management experience  Entrepreneurial Experience  Technical experience  \
# 0                    7.0                         0.0                   2.5
# 1                   19.6                         9.9                   0.0
# 2                   10.3                         0.0                   6.7
# 3                    0.0                         0.0                   4.1
# 4                    5.5                         0.0                   0.0
#
#   Location                                           Vertical  Speed_avg  \
# 0    other  Carsharing,Micro-mobility,Mobility tech,Ridesh...   0.511111
# 1    other                      Cryptocurrency and blockchain   0.170841
# 2    other  Carsharing,Micro-mobility,Mobility tech,Ridesh...   0.123585
# 3   london                                           Foodtech   0.243902
# 4    other                      Cryptocurrency and blockchain   1.073593
#
#    relevance  Founded Company Value
# 0          0             22450000.0
# 1          0             11852455.0
# 2          0             22450000.0
# 3          0               350410.0
# 4          0             30000000.0

# %%
def get_success_binary_level(value):
    if value > 1000000000:
        return 'successful'
    else:
        return 'Not successful'

# Apply this function to 'Founded Company Value'
final_result_df['binary success'] = final_result_df['Founded Company Value'].apply(get_success_binary_level)

final_result_df
# Out:
#       FounderID  CompanyID  CareerID  Number of professional experience  \
# 0             1      19921    216950                                  2
# 1             3      17160     79402                                  8
# 2             6      19921        39                                  7
# 3            13      20739       107                                  3
# 4            28      50729       223                                  7
# ...         ...        ...       ...                                ...
# 1818      25176     161268    333056                                  8
# 1820      25262     121205    222394                                  1
# 1821      25262     121204    258565                                  2
# 1822      25746     127266    238807                                  4
# 1824      25746     152400    312807                                  7
#
#       Number of companies that worked for  Total Work Years  \
# 0                                       1               7.0
# 1                                       8              31.1
# 2                                       6              18.9
# 3                                       3               7.1
# 4                                       7               7.2
# ...                                   ...               ...
# 1818                                    6              20.7
# 1820                                    1               6.5
# 1821                                    2               8.8
# 1822                                    4              14.6
# 1824                                    5              19.6
#
#       Industry Experience  Management experience  Entrepreneurial Experience  \
# 0                     0.0                    7.0                         0.0
# 1                     0.0                   19.6                         9.9
# 2                     0.0                   10.3                         0.0
# 3                     0.0                    0.0                         0.0
# 4                     0.0                    5.5                         0.0
# ...                   ...                    ...                         ...
# 1818                 11.6                    2.8                        12.7
# 1820                  0.0                    6.5                         0.0
# 1821                  0.0                    8.8                         2.3
# 1822                  0.0                    2.6                         9.4
# 1824                  0.0                    5.9                        12.7
#
#       Technical experience       Location  \
# 0                      2.5          other
# 1                      0.0          other
# 2                      6.7          other
# 3                      4.1         london
# 4                      0.0          other
# ...                    ...            ...
# 1818                   0.0          other
# 1820                   0.0          other
# 1821                   0.0  san francisco
# 1822                   2.6        toronto
# 1824                   4.8          other
#
#                                                Vertical  Speed_avg  relevance  \
# 0     Carsharing,Micro-mobility,Mobility tech,Ridesh...   0.511111          0
# 1                         Cryptocurrency and blockchain   0.170841          0
# 2     Carsharing,Micro-mobility,Mobility tech,Ridesh...   0.123585          0
# 3                                              Foodtech   0.243902          0
# 4                         Cryptocurrency and blockchain   1.073593          0
# ...                                                 ...        ...        ...
# 1818  Artificial intelligence and machine learning (...   0.644841          0
# 1820                                    Restaurant tech   0.000000          0
# 1821        Augmented reality (AR),Virtual reality (VR)   0.000000          0
# 1822                                             HRtech   0.480769          0
# 1824                                                NaN   0.274725          0
#
#       Founded Company Value  binary success
# 0                22450000.0  Not successful
# 1                11852455.0  Not successful
# 2                22450000.0  Not successful
# 3                  350410.0  Not successful
# 4                30000000.0  Not successful
# ...                     ...             ...
# 1818               875000.0  Not successful
# 1820               750000.0  Not successful
# 1821            404682445.0  Not successful
# 1822             12500000.0  Not successful
# 1824              3808640.0  Not successful
#
# [1801 rows x 16 columns]

# %%
def get_success_multi_level(value):
    if value > 1000000000:
        return 'Highly successful'
    elif 100000000 < value <= 1000000000:
        return 'Successful'
    elif 50000000 < value <= 100000000:
        return 'Moderately Successful'
    elif 10000000 < value <= 50000000:
        return 'Promising'
    else:
        return 'Not successful'

# Apply this function to 'Founded Company Value'
final_result_df['Level of success'] = final_result_df['Founded Company Value'].apply(get_success_multi_level)

final_result_df
# Out:
#       FounderID  CompanyID  CareerID  Number of professional experience  \
# 0             1      19921    216950                                  2
# 1             3      17160     79402                                  8
# 2             6      19921        39                                  7
# 3            13      20739       107                                  3
# 4            28      50729       223                                  7
# ...         ...        ...       ...                                ...
# 1818      25176     161268    333056                                  8
# 1820      25262     121205    222394                                  1
# 1821      25262     121204    258565                                  2
# 1822      25746     127266    238807                                  4
# 1824      25746     152400    312807                                  7
#
#       Number of companies that worked for  Total Work Years  \
# 0                                       1               7.0
# 1                                       8              31.1
# 2                                       6              18.9
# 3                                       3               7.1
# 4                                       7               7.2
# ...                                   ...               ...
# 1818                                    6              20.7
# 1820                                    1               6.5
# 1821                                    2               8.8
# 1822                                    4              14.6
# 1824                                    5              19.6
#
#       Industry Experience  Management experience  Entrepreneurial Experience  \
# 0                     0.0                    7.0                         0.0
# 1                     0.0                   19.6                         9.9
# 2                     0.0                   10.3                         0.0
# 3                     0.0                    0.0                         0.0
# 4                     0.0                    5.5                         0.0
# ...                   ...                    ...                         ...
# 1818                 11.6                    2.8                        12.7
# 1820                  0.0                    6.5                         0.0
# 1821                  0.0                    8.8                         2.3
# 1822                  0.0                    2.6                         9.4
# 1824                  0.0                    5.9                        12.7
#
#       Technical experience       Location  \
# 0                      2.5          other
# 1                      0.0          other
# 2                      6.7          other
# 3                      4.1         london
# 4                      0.0          other
# ...                    ...            ...
# 1818                   0.0          other
# 1820                   0.0          other
# 1821                   0.0  san francisco
# 1822                   2.6        toronto
# 1824                   4.8          other
#
#                                                Vertical  Speed_avg  relevance  \
# 0     Carsharing,Micro-mobility,Mobility tech,Ridesh...   0.511111          0
# 1                         Cryptocurrency and blockchain   0.170841          0
# 2     Carsharing,Micro-mobility,Mobility tech,Ridesh...   0.123585          0
# 3                                              Foodtech   0.243902          0
# 4                         Cryptocurrency and blockchain   1.073593          0
# ...                                                 ...        ...        ...
# 1818  Artificial intelligence and machine learning (...   0.644841          0
# 1820                                    Restaurant tech   0.000000          0
# 1821        Augmented reality (AR),Virtual reality (VR)   0.000000          0
# 1822                                             HRtech   0.480769          0
# 1824                                                NaN   0.274725          0
#
#       Founded Company Value  binary success Level of success
# 0                22450000.0  Not successful        Promising
# 1                11852455.0  Not successful        Promising
# 2                22450000.0  Not successful        Promising
# 3                  350410.0  Not successful   Not successful
# 4                30000000.0  Not successful        Promising
# ...                     ...             ...              ...
# 1818               875000.0  Not successful   Not successful
# 1820               750000.0  Not successful   Not successful
# 1821            404682445.0  Not successful       Successful
# 1822             12500000.0  Not successful        Promising
# 1824              3808640.0  Not successful   Not successful
#
# [1801 rows x 17 columns]

# %%
final_result_df.columns
# Out:
# Index(['FounderID', 'CompanyID', 'CareerID',
#        'Number of professional experience',
#        'Number of companies that worked for', 'Total Work Years',
#        'Industry Experience', 'Management experience',
#        'Entrepreneurial Experience', 'Technical experience', 'Location',
#        'Vertical', 'Speed_avg', 'relevance', 'Founded Company Value',
#        'binary success', 'Level of success'],
#       dtype='object')

# %% [markdown]
# Here, we have the final dataset ready for our prediction model. The first three columns represent the IDs related to the founding experience. Columns four to fourteen are the explanatory variables, and the last three columns are the response variables.
